# %% [markdown]
# Objective of project:
# - Create a tool which other team members can use to analyse trends in Government Procurement, based on 2015 data and future data.
# - Identify high value add procurement opportunities which currently go to foreign companies, but could have gone to local companies.
# - Identify insights behind trends in government procurement (e.g. which month of the year do most procurements take place?)
#
#
# A. Visualisation of data
# 1. Total number of agencies involved
# 2. The number of procurements conducted by each agency in 2015
# 3. The total awarded amount by each agency in 2015
# 4. The average value each procurement by each agency in 2015
# 5. Top procurements by value in 2015
# 6. List out all procurements by specified agency in 2015
#
#
# B. Cleaning of Dataset
# 1. Remove supposedly erroneous entries (e.g. expensive catering by DSTA?)
#
#
# C. Analysis
# 1. Differentiate amongst different types of procurements (e.g. services, products, value add)
#     - a. Clustering
# 2. Differentiate amongst different types of suppliers (e.g. local companies, foreign incorporated companies, local subsidiaries of foreign companies)
#     - a. Clustering
# 3. Which are the top 5 agencies which conduct high value add procurements

# %% [markdown]
# # Initialisation

# %%
import pandas as pd

import numpy as np
import csv
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

#Visualisation Libraries
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
pd.set_option('display.max_columns', 5)

# %matplotlib inline

# increase default figure and font sizes for easier viewing
#plt.rcParams['figure.figsize'] = (8, 6)
#plt.rcParams['font.size'] = 14

#Open CSV file containing - Singapore Government Procurement Record for 2015
#Source: data.gov.sg
filename = '/Users/xuanrong/mystuff/git/GovtProcurement/government-procurement/government-procurement-via-gebiz-2015.csv'
cols = ['Tender Number', 'Agency', 'Tender Description', 'Award Date', 'Tender Detail Status', 'Supplier Name', 'Total Awarded Amount']
gp_original = pd.read_csv(filename, header=0, names=cols)

#Remove all rows where there was "no awards"
gp_original = gp_original[gp_original['Tender Detail Status'] != 'Awarded to No Suppliers']

million_converter = lambda x: x / 1000000

# %%
# Add new column indicating the parent agency

filename_2 = '/Users/xuanrong/mystuff/git/GovtProcurement/Agency_List.csv'
cols_2 = ['Agency','Parent Agency']
gp_parent_agency = pd.read_csv(filename_2, header=0,names=cols_2)
gp = pd.merge(gp_original, gp_parent_agency, on='Agency')

# %% [markdown]
# # Count Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(ngram_range=(1,5))

# Create a vector where each row is bag-of-words for a single quote
vectorizer.fit(gp['Supplier Name']) 

vectorizer.get_feature_names()
# Out:
# [u'01',
#  u'01 computer',
#  u'01 computer system',
#  u'01 computer system pte',
#  u'01 computer system pte ltd',
#  u'1971',
#  u'1971 pte',
#  u'1971 pte ltd',
#  u'1978',
#  u'1978 private',
#  u'1978 private limited',
#  u'1986',
#  u'1986 pte',
#  u'1986 pte ltd',
#  u'1988',
#  u'1988 pte',
#  u'1988 pte ltd',
#  u'1995',
#  u'1995 pte',
#  u'1995 pte ltd',
#  u'1996',
#  u'1996 pte',
#  u'1996 pte ltd',
#  u'1999',
#  u'1999 pte',
#  u'1999 pte ltd',
#  u'1survey',
#  u'1survey associates',
#  u'2001',
#  u'2001 pte',
#  u'2001 pte ltd',
#  u'2002',
#  u'2002 pte',
#  u'21',
#  u'21 engineering',
#  u'21 engineering pte',
#  u'21 engineering pte ltd',
#  u'21 equipment',
#  u'21 equipment pte',
#  u'21 equipment pte ltd',
#  u'21 pte',
#  u'21 pte ltd',
#  u'22',
#  u'22 pte',
#  u'22 pte ltd',
#  u'23',
#  u'23 degree',
#  u'23 degree architects',
#  u'23 degree architects pte',
#  u'23 degree architects pte ltd',
#  u'28',
#  u'28 project',
#  u'28 project trading',
#  u'28 project trading pte',
#  u'28 project trading pte ltd',
#  u'360',
#  u'360 incorporated',
#  u'3818',
#  u'3818 asia',
#  u'3818 asia engineering',
#  u'3818 asia engineering pte',
#  u'3818 asia engineering pte ltd',
#  u'388',
#  u'388 pte',
#  u'388 pte ltd',
#  u'3ad',
#  u'3ad group',
#  u'3ad group pte',
#  u'3ad group pte ltd',
#  u'3d',
#  u'3d networks',
#  u'3d networks singapore',
#  u'3d networks singapore pte',
#  u'3d networks singapore pte ltd',
#  u'3m',
#  u'3m technologies',
#  u'3m technologies pte',
#  u'3m technologies pte ltd',
#  u'3p',
#  u'3p solutions',
#  u'3p solutions pte',
#  u'3p solutions pte ltd',
#  u'3waves',
#  u'3waves energy',
#  u'3waves energy pte',
#  u'3waves energy pte ltd',
#  u'800',
#  u'800 super',
#  u'800 super waste',
#  u'800 super waste management',
#  u'800 super waste management pte',
#  u'88',
#  u'88 interior',
#  u'88 interior design',
#  u'88 interior design pte',
#  u'88 interior design pte ltd',
#  u'90',
#  u'90 pte',
#  u'90 pte ltd',
#  u'9g',
#  u'9g elevator',
#  u'9g elevator pte',
#  u'9g elevator pte ltd',
#  u'aa',
#  u'aa access',
#  u'aa access partnership',
#  u'aa access partnership limited',
#  u'aa vehicle',
#  u'aa vehicle inspection',
#  u'aa vehicle inspection centre',
#  u'aa vehicle inspection centre pte',
#  u'aadvantage',
#  u'aadvantage consulting',
#  u'aadvantage consulting group',
#  u'aadvantage consulting group pte',
#  u'aadvantage consulting group pte ltd',
#  u'aam',
#  u'aam pty',
#  u'aam pty ltd',
#  u'aaron',
#  u'aaron wills',
#  u'aaron wills co',
#  u'aaron wills co private',
#  u'aaron wills co private limited',
#  u'aaxonn',
#  u'aaxonn pte',
#  u'aaxonn pte ltd',
#  u'ab',
#  u'ab associates',
#  u'ab associates pte',
#  u'ab associates pte ltd',
#  u'ab sciex',
#  u'ab sciex distribution',
#  u'abb',
#  u'abb pte',
#  u'abb pte ltd',
#  u'abbott',
#  u'abbott informatics',
#  u'abbott informatics singapore',
#  u'abbott informatics singapore pte',
#  u'abbott informatics singapore pte limited',
#  u'abeltec',
#  u'abeltec international',
#  u'abeltec international pte',
#  u'abeltec international pte ltd',
#  u'abi',
#  u'abi research',
#  u'abi research singapore',
#  u'abi research singapore pte',
#  u'abi research singapore pte ltd',
#  u'abingdon',
#  u'abingdon construction',
#  u'abingdon construction pte',
#  u'abingdon construction pte ltd',
#  u'abl',
#  u'abl consultants',
#  u'abl consultants pte',
#  u'abl consultants pte ltd',
#  u'absolute',
#  u'absolute maintenance',
#  u'absolute maintenance services',
#  u'absolute maintenance services pte',
#  u'absolute maintenance services pte ltd',
#  u'abtus',
#  u'abtus singapore',
#  u'abtus singapore pte',
#  u'abtus singapore pte ltd',
#  u'abv',
#  u'abv systems',
#  u'abv systems pte',
#  u'abv systems pte ltd',
#  u'academy',
#  u'academy communication',
#  u'academy communication pte',
#  u'academy communication pte ltd',
#  u'academy pte',
#  u'academy pte ltd',
#  u'accel',
#  u'accel systems',
#  u'accel systems technologies',
#  u'accel systems technologies pte',
#  u'accel systems technologies pte ltd',
#  u'accenture',
#  u'accenture pte',
#  u'accenture pte ltd',
#  u'access',
#  u'access and',
#  u'access and distribution',
#  u'access and distribution hk',
#  u'access and distribution hk limited',
#  u'access partnership',
#  u'access partnership limited',
#  u'access pte',
#  u'access pte ltd',
#  u'access solutions',
#  u'access solutions pte',
#  u'access solutions pte ltd',
#  u'acclaim',
#  u'acclaim insurance',
#  u'acclaim insurance brokers',
#  u'acclaim insurance brokers pte',
#  u'acclaim insurance brokers pte ltd',
#  u'acclivis',
#  u'acclivis technologies',
#  u'acclivis technologies and',
#  u'acclivis technologies and solutions',
#  u'acclivis technologies and solutions pte',
#  u'accredited',
#  u'accredited checkers',
#  u'acculex',
#  u'acculex solutions',
#  u'acculex solutions pte',
#  u'acculex solutions pte ltd',
#  u'accurate',
#  u'accurate general',
#  u'accurate general corp',
#  u'ace',
#  u'ace insurance',
#  u'ace insurance limited',
#  u'ace of',
#  u'ace of vase',
#  u'ace of vase pte',
#  u'ace of vase pte ltd',
#  u'ace power',
#  u'ace power control',
#  u'ace power control pte',
#  u'ace power control pte ltd',
#  u'ace recreation',
#  u'ace recreation sports',
#  u'ace recreation sports wellness',
#  u'ace recreation sports wellness pte',
#  u'ace tone',
#  u'ace tone solutions',
#  u'ace water',
#  u'ace water pte',
#  u'ace water pte ltd',
#  u'aceproject',
#  u'aceproject construction',
#  u'aceproject construction pte',
#  u'aceproject construction pte ltd',
#  u'acer',
#  u'acer computer',
#  u'acer computer singapore',
#  u'acer computer singapore pte',
#  u'acer computer singapore pte ltd',
#  u'acerpacer',
#  u'acerpacer consulting',
#  u'acerpacer consulting pte',
#  u'acerpacer consulting pte ltd',
#  u'aces',
#  u'aces learning',
#  u'aces learning hub',
#  u'aces learning hub pte',
#  u'aces learning hub pte ltd',
#  u'aces system',
#  u'aces system development',
#  u'aces system development pte',
#  u'aces system development pte ltd',
#  u'acesian',
#  u'acesian star',
#  u'acesian star pte',
#  u'acesian star pte ltd',
#  u'ach',
#  u'ach development',
#  u'ach development pte',
#  u'ach development pte ltd',
#  u'achema',
#  u'achema pte',
#  u'achema pte ltd',
#  u'achievers',
#  u'achievers outdoor',
#  u'achievers outdoor consultants',
#  u'achievers outdoor consultants pte',
#  u'achievers outdoor consultants pte ltd',
#  u'achievers pte',
#  u'achievers pte ltd',
#  u'acl',
#  u'acl services',
#  u'acl services singapore',
#  u'acl services singapore pte',
#  u'acl services singapore pte ltd',
#  u'acme',
#  u'acme chemicals',
#  u'acme chemicals far',
#  u'acme chemicals far east',
#  u'acme chemicals far east pte',
#  u'acorn',
#  u'acorn training',
#  u'acorn training pte',
#  u'acorn training pte ltd',
#  u'acoustic',
#  u'acoustic group',
#  u'acoustic group pte',
#  u'acoustic group pte ltd',
#  u'acoustics',
#  u'acoustics systems',
#  u'acoustics systems pte',
#  u'acoustics systems pte ltd',
#  u'acp',
#  u'acp office',
#  u'acp office supplies',
#  u'acp office supplies pte',
#  u'acp office supplies pte ltd',
#  u'acre',
#  u'acre engineering',
#  u'acre engineering pte',
#  u'acre engineering pte ltd',
#  u'acromec',
#  u'acromec engineers',
#  u'acromec engineers pte',
#  u'acromec engineers pte ltd',
#  u'actc',
#  u'actc translation',
#  u'actc translation centre',
#  u'actc translation centre pte',
#  u'actc translation centre pte ltd',
#  u'actfast',
#  u'actfast medical',
#  u'actfast medical llc',
#  u'activate',
#  u'activate interactive',
#  u'activate interactive pte',
#  u'activate interactive pte ltd',
#  u'active',
#  u'active lifestyle',
#  u'active lifestyle pte',
#  u'active lifestyle pte ltd',
#  u'active pte',
#  u'active pte ltd',
#  u'activiste',
#  u'activiste pte',
#  u'activiste pte ltd',
#  u'ad',
#  u'ad pte',
#  u'ad pte ltd',
#  u'adam',
#  u'adam khoo',
#  u'adam khoo leadership',
#  u'adam khoo leadership company',
#  u'adam khoo leadership company pte',
#  u'adam khoo life',
#  u'adam khoo life skills',
#  u'adam khoo life skills company',
#  u'adam khoo outdoor',
#  u'adam khoo outdoor company',
#  u'adam khoo outdoor company pte',
#  u'addiction',
#  u'addiction advertising',
#  u'addiction advertising pte',
#  u'addiction advertising pte ltd',
#  u'addp',
#  u'addp architects',
#  u'addp architects llp',
#  u'adecco',
#  u'adecco personnel',
#  u'adecco personnel pte',
#  u'adecco personnel pte ltd',
#  u'adele',
#  u'adele educational',
#  u'adele educational psychology',
#  u'adele educational psychology services',
#  u'adelphi',
#  u'adelphi digital',
#  u'adelphi digital consulting',
#  u'adelphi digital consulting group',
#  u'adelphi digital consulting group pte',
#  u'ademco',
#  u'ademco far',
#  u'ademco far east',
#  u'ademco far east pte',
#  u'ademco far east pte ltd',
#  u'admaterials',
#  u'admaterials technologies',
#  u'admaterials technologies pte',
#  u'admaterials technologies pte ltd',
#  u'adnovum',
#  u'adnovum singapore',
#  u'adnovum singapore pte',
#  u'adnovum singapore pte ltd',
#  u'adonai',
#  u'adonai electronics',
#  u'adonai electronics services',
#  u'adrenalin',
#  u'adrenalin group',
#  u'adrenalin group pte',
#  u'adrenalin group pte ltd',
#  u'adsolution',
#  u'adtitude',
#  u'adtitude pte',
#  u'adtitude pte ltd',
#  u'advan',
#  u'advan engineering',
#  u'advan engineering pte',
#  u'advan engineering pte ltd',
#  u'advance',
#  u'advance laboratory',
#  u'advance laboratory system',
#  u'advance laboratory system engineering',
#  u'advance laboratory system engineering pte',
#  u'advance library',
#  u'advance library services',
#  u'advance library services pte',
#  u'advance library services pte ltd',
#  u'advance pinnacle',
#  u'advance pinnacle technologies',
#  u'advance pinnacle technologies private',
#  u'advance pinnacle technologies private limited',
#  u'advance sports',
#  u'advance sports technologies',
#  u'advance sports technologies pte',
#  u'advance sports technologies pte ltd',
#  u'advance tec',
#  u'advance tec engineering',
#  u'advance tec engineering pte',
#  u'advance tec engineering pte ltd',
#  u'advanced',
#  u'advanced cae',
#  u'advanced cae pte',
#  u'advanced cae pte ltd',
#  u'advanced construction',
#  u'advanced construction engineering',
#  u'advanced construction engineering pte',
#  u'advanced construction engineering pte ltd',
#  u'advanced material',
#  u'advanced material engineering',
#  u'advanced material engineering pte',
#  u'advanced material engineering pte ltd',
#  u'advanced pyrotechnic',
#  u'advanced pyrotechnic materials',
#  u'advanced pyrotechnic materials private',
#  u'advanced pyrotechnic materials private limited',
#  u'advanced research',
#  u'advanced research and',
#  u'advanced research and education',
#  u'advanced research and education network',
#  u'advanced vacuum',
#  u'advanced vacuum scandinavia',
#  u'advanced vacuum scandinavia ab',
#  u'advancelab',
#  u'advancelab pte',
#  u'advancelab pte ltd',
#  u'advantage',
#  u'advantage health',
#  u'advantage health benefits',
#  u'advantage health benefits pte',
#  u'advantage health benefits pte ltd',
#  u'advantage pte',
#  u'advantage pte ltd',
#  u'adventra',
#  u'adventra pte',
#  u'adventra pte ltd',
#  u'adventure',
#  u'adventure plus',
#  u'adventure plus pte',
#  u'adventure plus pte ltd',
#  u'adventure pte',
#  u'adventure pte ltd',
#  u'adventure systems',
#  u'adventure systems pte',
#  u'adventure systems pte ltd',
#  u'adventurer',
#  u'adventurer singapore',
#  u'adventurer singapore pte',
#  u'adventurer singapore pte ltd',
#  u'adventurer sports',
#  u'adventurer sports event',
#  u'adventurer sports event pte',
#  u'adventurer sports event pte ltd',
#  u'advertising',
#  u'advertising consultants',
#  u'advertising marketing',
#  u'advertising marketing pte',
#  u'advertising marketing pte ltd',
#  u'advertising pte',
#  u'advertising pte ltd',
#  u'advisors',
#  u'advisors inc',
#  u'advisory',
#  u'advisory pte',
#  u'advisory pte ltd',
#  u'advisory services',
#  u'advisory services pte',
#  u'advisory services pte ltd',
#  u'advisory singapore',
#  u'advisory singapore pte',
#  u'advisory singapore pte ltd',
#  u'adworld',
#  u'adworld pte',
#  u'adworld pte ltd',
#  u'aecom',
#  u'aecom singapore',
#  u'aecom singapore pte',
#  u'aecom singapore pte ltd',
#  u'aedas',
#  u'aedas pte',
#  u'aedas pte ltd',
#  u'aedge',
#  u'aedge holdings',
#  u'aedge holdings pte',
#  u'aedge holdings pte ltd',
#  u'aegis',
#  u'aegis engineering',
#  u'aegis engineering pte',
#  u'aegis engineering pte ltd',
#  u'aegis insurance',
#  u'aegis insurance services',
#  u'aegis insurance services pte',
#  u'aegis insurance services pte ltd',
#  u'aeradio',
#  u'aeradio technology',
#  u'aeradio technology pte',
#  u'aeradio technology pte ltd',
#  u'aero',
#  u'aero marine',
#  u'aero marine vehicles',
#  u'aetha',
#  u'aetha consulting',
#  u'aetha consulting limited',
#  u'aetos',
#  u'aetos security',
#  u'aetos security management',
#  u'aetos security management pte',
#  u'aetos security management pte ltd',
#  u'aetos training',
#  u'aetos training academy',
#  u'aetos training academy pte',
#  u'aetos training academy pte ltd',
#  u'afon',
#  u'afon pte',
#  u'afon pte ltd',
#  u'after',
#  u'after care',
#  u'after care association',
#  u'aftershock',
#  u'aftershock pc',
#  u'aftershock pc pte',
#  u'aftershock pc pte ltd',
#  u'ag',
#  u'ag singapore',
#  u'ag singapore branch',
#  u'agape',
#  u'agape connecting',
#  u'agape connecting people',
#  u'agape connecting people pte',
#  u'agape connecting people pte ltd',
#  u'agape professional',
#  u'agape professional development',
#  u'agape professional development consultancy',
#  u'agarwal',
#  u'agarwal sumit',
#  u'agb',
#  u'agb education',
#  u'agb education centre',
#  u'agb education centre pte',
#  u'agb education centre pte ltd',
#  u'age',
#  u'age neonlight',
#  u'age neonlight signcrafts',
#  u'age neonlight signcrafts pte',
#  u'age neonlight signcrafts pte ltd',
#  u'agencies',
#  u'agencies marine',
#  u'agencies marine services',
#  u'agencies marine services pte',
#  u'agencies marine services pte ltd',
#  u'agency',
#  u'agency and',
#  u'agency and investigation',
#  u'agency and investigation pte',
#  u'agency and investigation pte ltd',
#  u'agency corporation',
#  u'agency corporation pte',
#  u'agency corporation pte ltd',
#  u'agency pte',
#  u'agency pte ltd',
#  u'agenda',
#  u'agent',
#  u'aggasys',
#  u'aggasys solutions',
#  u'aggasys solutions pte',
#  u'aggasys solutions pte ltd',
#  u'aggreko',
#  u'aggreko singapore',
#  u'aggreko singapore pte',
#  u'aggreko singapore pte ltd',
#  u'agilent',
#  u'agilent technologies',
#  u'agilent technologies singapore',
#  u'agilent technologies singapore sales',
#  u'agilent technologies singapore sales pte',
#  u'agility',
#  u'agility fairs',
#  u'agility fairs events',
#  u'agility fairs events logistics',
#  u'agility fairs events logistics pte',
#  u'agitech',
#  u'agitech innovations',
#  u'agitech innovations private',
#  u'agitech innovations private limited',
#  u'ago',
#  u'ago pte',
#  u'ago pte ltd',
#  u'agog',
#  u'agog expo',
#  u'agog expo pte',
#  u'agog expo pte ltd',
#  u'agri',
#  u'agri opus',
#  u'agri opus proba',
#  u'agri opus proba pte',
#  u'agri opus proba pte ltd',
#  u'agricultural',
#  u'agricultural tractors',
#  u'agricultural tractors spares',
#  u'agricultural tractors spares pte',
#  u'agricultural tractors spares pte ltd',
#  u'agriculture',
#  u'agriculture pte',
#  u'agriculture pte ltd',
#  u'agro',
#  u'agro technic',
#  u'agro technic pte',
#  u'agro technic pte ltd',
#  u'ah',
#  u'ah boon',
#  u'ah boon civil',
#  u'ah boon civil engineering',
#  u'ah boon civil engineering building',
#  u'ahead',
#  u'ahead group',
#  u'ahead group plc',
#  u'aig',
#  u'aig asia',
#  u'aig asia pacific',
#  u'aig asia pacific insurance',
#  u'aig asia pacific insurance pte',
#  u'aik',
#  u'aik construction',
#  u'aik construction pte',
#  u'aik construction pte ltd',
#  u'aik engineering',
#  u'aik engineering pte',
#  u'aik engineering pte ltd',
#  u'aik hong',
#  u'aik hong construction',
#  u'aik hong construction pte',
#  u'aik hong construction pte ltd',
#  u'aik leong',
#  u'aik leong plumbing',
#  u'aik leong plumbing construction',
#  u'aik leong plumbing construction pte',
#  u'aik moh',
#  u'aik moh paints',
#  u'aik moh paints chemicals',
#  u'aik moh paints chemicals pte',
#  u'aik san',
#  u'aik san construction',
#  u'aik san construction pte',
#  u'aik san construction pte ltd',
#  u'aik sun',
#  u'aik sun demolition',
#  u'aik sun demolition engineering',
#  u'aik sun demolition engineering pte',
#  u'aikly',
#  u'aikly paints',
#  u'aikly paints and',
#  u'aikly paints and chemical',
#  u'aikly paints and chemical pte',
#  u'aims',
#  u'aims productions',
#  u'aims productions llp',
#  u'air',
#  u'air air',
#  u'air air services',
#  u'air air services pte',
#  u'air air services pte ltd',
#  u'air con',
#  u'air con services',
#  u'air con services pte',
#  u'air con services pte ltd',
#  u'air conditioning',
#  u'air conditioning electrical',
#  u'air conditioning electrical engineering',
#  u'air conditioning electrical engineering pte',
#  u'air conditioning engineering',
#  u'air conditioning engineering pte',
#  u'air conditioning engineering pte ltd',
#  u'air conditioning pte',
#  u'air conditioning pte ltd',
#  u'air liquide',
#  u'air liquide private',
#  u'air liquide private limited',
#  u'air products',
#  u'air products singapore',
#  u'air products singapore pte',
#  u'air products singapore pte ltd',
#  u'air quality',
#  u'air quality group',
#  u'air quality group pte',
#  u'air quality group pte ltd',
#  u'air services',
#  u'air services pte',
#  u'air services pte ltd',
#  u'air transport',
#  u'air transport training',
#  u'air transport training college',
#  u'air transport training college pte',
#  u'aire',
#  u'aire builder',
#  u'aire builder distribution',
#  u'aire builder distribution pte',
#  u'aire builder distribution pte ltd',
#  u'airfresh',
#  u'airfresh building',
#  u'airfresh building services',
#  u'airfresh building services pte',
#  u'airfresh building services pte ltd',
#  u'airport',
#  u'airport services',
#  u'airport services pte',
#  u'airport services pte ltd',
#  u'aitbiotech',
#  u'aitbiotech pte',
#  u'aitbiotech pte ltd',
#  u'aja',
#  u'aja international',
#  u'aja international inc',
#  u'ajamil',
#  u'ajamil partners',
#  u'ajamil partners inc',
#  u'al',
#  u'al technologies',
#  u'al technologies pte',
#  u'al technologies pte ltd',
#  u'alc',
#  u'alc technologies',
#  u'alc technologies pte',
#  u'alc technologies pte ltd',
#  u'alcatel',
#  u'alcatel lucent',
#  u'alcatel lucent singapore',
#  u'alcatel lucent singapore pte',
#  u'alcatel lucent singapore pte ltd',
#  u'alchemy',
#  u'alchemy singapore',
#  u'alchemy singapore pte',
#  u'alchemy singapore pte ltd',
#  u'alcotrad',
#  u'alcotrad pte',
#  u'alcotrad pte ltd',
#  u'aldrich',
#  u'aldrich pte',
#  u'aldrich pte ltd',
#  u'alexander',
#  u'alexander dennis',
#  u'alexander dennis asia',
#  u'alexander dennis asia pacific',
#  u'alexander dennis asia pacific limited',
#  u'alfa',
#  u'alfa tech',
#  u'alfa tech vestasia',
#  u'alfa tech vestasia pte',
#  u'alfa tech vestasia pte ltd',
#  u'alice',
#  u'align',
#  u'align sma',
#  u'align sma pte',
#  u'align sma pte ltd',
#  u'alion',
#  u'alion science',
#  u'alion science and',
#  u'alion science and technology',
#  u'alion science and technology corporation',
#  u'alkalom',
#  u'alkalom eclat',
#  u'all',
#  u'all best',
#  u'all best photocopy',
#  u'all best photocopy printing',
#  u'all big',
#  u'all big frozen',
#  u'all big frozen food',
#  u'all big frozen food pte',
#  u'all eights',
#  u'all eights singapore',
#  u'all eights singapore private',
#  u'all eights singapore private limited',
#  u'all link',
#  u'all link 21',
#  u'all link 21 engineering',
#  u'all link 21 engineering pte',
#  u'allan',
#  u'allan defence',
#  u'allan defence technologies',
#  u'allan defence technologies pte',
#  u'allan defence technologies pte ltd',
#  u'allen',
#  u'allen gledhill',
#  u'allen gledhill llp',
#  u'allen kaplan',
#  u'alliance',
#  u'alliance asia',
#  u'alliance asia pte',
#  u'alliance asia pte ltd',
#  u'alliance consulting',
#  u'alliance consulting engineers',
#  u'alliance consulting engineers pte',
#  u'alliance consulting engineers pte ltd',
#  u'alliance llp',
#  u'alliance technology',
#  u'alliance technology international',
#  u'alliance technology international pte',
#  u'alliance technology international pte ltd',
#  u'alliances',
#  u'alliances pte',
#  u'alliances pte ltd',
#  u'allied',
#  u'allied creations',
#  u'allied moving',
#  u'allied moving services',
#  u'allied moving services pte',
#  u'allied moving services pte ltd',
#  u'allied services',
#  u'allied services pvt',
#  u'allied services pvt ltd',
#  u'allmaster',
#  u'allmaster enterprise',
#  u'allpets',
#  u'allpets asia',
#  u'allpets asia pte',
#  u'allpets asia pte ltd',
#  u'alpha',
#  u'alpha analytical',
#  u'alpha analytical pte',
#  u'alpha analytical pte ltd',
#  u'alphamed',
#  u'alphamed pte',
#  u'alphamed pte ltd',
#  u'alphine',
#  u'alphine builders',
#  u'alphine builders pte',
#  u'alphine builders pte ltd',
#  u'als',
#  u'als technichem',
#  u'als technichem singapore',
#  u'als technichem singapore pte',
#  u'als technichem singapore pte ltd',
#  u'alsale',
#  u'alsale marketing',
#  u'alsale marketing pte',
#  u'alsale marketing pte ltd',
#  u'altrus',
#  u'altrus pte',
#  u'altrus pte ltd',
#  u'aluminium',
#  u'aluminium design',
#  u'aluminium design contract',
#  u'aluminium design contract pte',
#  u'aluminium design contract pte ltd',
#  u'alx',
#  u'alx private',
#  u'alx private limited',
#  u'amazing',
#  u'amazing explorer',
#  u'amazing explorer pte',
#  u'amazing explorer pte ltd',
#  u'ambulance',
#  u'ambulance pte',
#  u'ambulance pte ltd',
#  u'amcon',
#  u'amcon integration',
#  u'amcon integration llp',
#  u'amdon',
#  u'amdon consulting',
#  u'amdon consulting pte',
#  u'amdon consulting pte ltd',
#  u'amici',
#  u'amici events',
#  u'amici events catering',
#  u'amici events catering pte',
#  u'amici events catering pte ltd',
#  u'amicus',
#  u'amicus engineering',
#  u'amicus engineering pte',
#  u'amicus engineering pte ltd',
#  u'amitie',
#  u'amitie international',
#  u'amitie international pte',
#  u'amitie international pte ltd',
#  u'amphasis',
#  u'amphasis design',
#  u'amphasis design pte',
#  u'amphasis design pte ltd',
#  u'amundi',
#  u'amundi singapore',
#  u'amundi singapore limited',
#  u'an',
#  u'an academy',
#  u'an academy pte',
#  u'an academy pte ltd',
#  u'an engineering',
#  u'an engineering pte',
#  u'an engineering pte ltd',
#  u'anacle',
#  u'anacle systems',
#  u'anacle systems pte',
#  u'anacle systems pte ltd',
#  u'analysis',
#  u'analysis pte',
#  u'analysis pte ltd',
#  u'analysys',
#  u'analysys mason',
#  u'analysys mason limited',
#  u'analytical',
#  u'analytical limited',
#  u'analytical pte',
#  u'analytical pte ltd',
#  u'analytical technologies',
#  u'analytical technologies pte',
#  u'analytical technologies pte ltd',
#  u'analytics',
#  u'analytics group',
#  u'analytics group pte',
#  u'analytics group pte ltd',
#  u'ancell',
#  u'ancell enterprise',
#  u'ancell enterprise pte',
#  u'ancell enterprise pte ltd',
#  u'anchorage',
#  u'anchorage construction',
#  u'anchorage construction co',
#  u'anchorage construction co pte',
#  u'anchorage construction co pte ltd',
#  u'and',
#  u'and chemical',
#  u'and chemical pte',
#  u'and chemical pte ltd',
#  u'and company',
#  u'and company private',
#  u'and company private limited',
#  u'and concept',
#  u'and concept holdings',
#  u'and concept holdings pte',
#  u'and concept holdings pte ltd',
#  u'and construction',
#  u'and construction pte',
#  u'and construction pte ltd',
#  u'and consulting',
#  u'and consulting pte',
#  u'and consulting pte ltd',
#  u'and contractors',
#  u'and contractors pte',
#  u'and contractors pte ltd',
#  u'and designs',
#  u'and development',
#  u'and development pte',
#  u'and development pte ltd',
#  u'and distribution',
#  u'and distribution hk',
#  u'and distribution hk limited',
#  u'and education',
#  u'and education network',
#  u'and education network singaren',
#  u'and electrical',
#  u'and electrical pte',
#  u'and electrical pte ltd',
#  u'and engineering',
#  u'and engineering pte',
#  u'and engineering pte ltd',
#  u'and excursion',
#  u'and excursion bus',
#  u'and instrumentation',
#  u'and instrumentation pte',
#  u'and instrumentation pte ltd',
#  u'and investigation',
#  u'and investigation pte',
#  u'and investigation pte ltd',
#  u'and land',
#  u'and land technologies',
#  u'and land technologies pte',
#  u'and land technologies pte ltd',
#  u'and learning',
#  u'and learning limited',
#  u'and management',
#  u'and management pte',
#  u'and management pte ltd',
#  u'and nanotech',
#  u'and nanotech co',
#  u'and nanotech co ltd',
#  u'and pixel',
#  u'and pixel pte',
#  u'and pixel pte ltd',
#  u'and rentals',
#  u'and rentals limited',
#  u'and schooling',
#  u'and schooling pte',
#  u'and schooling pte ltd',
#  u'and security',
#  u'and security consultants',
#  u'and security consultants pte',
#  ...]
